# %%
import matplotlib.pyplot as plt

# %%
plt.plot([100, 200, 300, 400, 500, 
          600, 700, 800, 900,1000, 
          1100, 1200, 1300, 1400, 1500, 
          1600, 1700, 1800, 1900, 2000],
         [0.81, 0.8528, 0.8488, 0.854, 0.856, 
          0.8624, 0.8648, 0.8672, 0.8696, 0.8696, 
          0.8692, 0.8688, 0.8692, 0.87, 0.87, 
          0.87, 0.8696, 0.8696, 0.8692, 0.8692],
         marker='o')
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.title('Accuracy on testing_data1.txt')
plt.show()
